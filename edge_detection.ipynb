# %% [markdown]
# <a href="https://colab.research.google.com/github/menduv/computer_vision_projects/blob/main/edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creating functions for edge detection in images and laying edges on images

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
from scipy import ndimage

# %%
def display_image_filename(filename, rotate = False, angle = 180):
  """read and display images"""
  image = cv2.imread(filename)
  return cv2_imshow(image)

def create_edges(image):
  '''creating edges from cv2 images'''
  # Convert the image to grayscale
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

  # Apply GaussianBlur to reduce noise and help edge detection
  blurred = cv2.GaussianBlur(gray, (5, 5), 0)

  # Apply Canny edge detector
  edged = cv2.Canny(blurred, 10, 100)

  return edged

# %%
def only_edges(filename, rotate = False, angle = 180):
  image = cv2.imread(filename)
  if rotate:
    image = ndimage.rotate(image, angle=angle, reshape=False)

  return create_edges(image)

# %%
cv2_imshow(only_edges("image.jpg"))
# Out:
# <PIL.Image.Image image mode=L size=763x1018>

# %%
def edgeonimage(filename, rotate = False, angle = 180):
    # Assuming you have the image loaded in the 'image' variable
    image = cv2.imread(filename)
    if rotate:
      image = ndimage.rotate(image, angle=angle, reshape=False)

    # Display the original image
    # cv2_imshow(image)

    edged = create_edges(image)

    # Create a copy of the original image
    result = image.copy()

    # Apply a mask using the edged image
    result[edged != 0] = [0, 255, 0]

    return result

# %%
cv2_imshow(edgeonimage('image.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=763x1018>

# %%
cv2_imshow(edgeonimage('image_2.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=700x1024>

# %%
cv2_imshow(only_edges('image_2.jpg'))
# Out:
# <PIL.Image.Image image mode=L size=700x1024>
